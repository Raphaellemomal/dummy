# %%
"""Code for Safety Module."""

import glob
from typing import List, Optional

import pandas as pd
import numpy as np
from loguru import logger

from tde import target
from tde.target.utils import read_parquet

# Define directories in use
RAW_DATA_DIR = "/home/owkin/project/target/raw_data"
PROCESS_DATA_DIR = "/home/owkin/project/target/processed_data"


def _reformat_ot_safety(df: pd.DataFrame, col_explode: str, cols_subset_ls: List[str]) -> pd.DataFrame:
    """Create a dataframe by exploding safetyLiabilities column."""
    # Create temporary dataframes to explode lists of dictionaries and flatten out values of interest into columns
    df_temp1 = df.explode(col_explode)
    # Drop rows with missing values in safetyLiabilities
    df_temp1.dropna(subset=[col_explode], inplace=True)
    df_temp1.reset_index(inplace=True)

    df_temp2 = df_temp1[col_explode].apply(pd.Series, dtype="object")
    df_temp3 = df_temp2.explode("biosamples")
    df_temp4 = df_temp3["biosamples"].apply(pd.Series, dtype="object")[["cellLabel", "tissueLabel"]]


    # Concatenate all temporary dataframes into one
    df_concat = pd.concat([df_temp1, df_temp2, df_temp4], axis=1)

    # Subset for columns of interest
    df_subset = df_concat[cols_subset_ls]

    return df_subset

# %%
# Working directory
# !pwd
# Out:
# /home/owkin/target_discovery_engine/tde/target

# %%
col_explode = "safetyLiabilities"
cols_subset_ls = ["gene_id", "cellLabel", "tissueLabel", "event", "datasource"]

files_ls = glob.glob(f"{RAW_DATA_DIR}/targets/*.parquet")

# Read in all parquet files into single dataframe
parquet_df_ls = [
    read_parquet(file_path=file, cols_subset_ls=["gene_id", "tractability", "safetyLiabilities"])
    for file in files_ls
]

df = pd.concat(parquet_df_ls, ignore_index=True)

# %%
df[df["safetyLiabilities"].notna()]
# Out:
#                gene_id                                       tractability  \
# 13     ENSG00000105641  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 31     ENSG00000138823  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 45     ENSG00000163586  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 55     ENSG00000169410  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 138    ENSG00000232810  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# ...                ...                                                ...
# 62070  ENSG00000163285  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 62354  ENSG00000050748  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 62367  ENSG00000111087  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 62432  ENSG00000181072  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
# 62435  ENSG00000185231  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
#
#                                        safetyLiabilities
# 13     [{'event': 'Cognitive Function, Decreased', 'e...
# 31     [{'event': 'Increased, Liver Steatosis', 'even...
# 45     [{'event': 'regulation of transcription factor...
# 55     [{'event': 'regulation of catalytic activity',...
# 138    [{'event': 'regulation of gene expression', 'e...
# ...                                                  ...
# 62070  [{'event': 'increased eating', 'eventId': 'HP_...
# 62354  [{'event': 'regulation of catalytic activity',...
# 62367  [{'event': 'regulation of transcription factor...
# 62432  [{'event': 'peripheral edema', 'eventId': None...
# 62435  [{'event': 'regulation of transcription factor...
#
# [503 rows x 3 columns]

# %%
# Reformat dataframe using _reformat_ot_safety function
safety_df = _reformat_ot_safety(df, col_explode ,cols_subset_ls)
safety_df
# Out:
#               gene_id cellLabel     tissueLabel  \
# 0     ENSG00000105641       NaN             NaN
# 1     ENSG00000105641       NaN             NaN
# 2     ENSG00000105641       NaN             NaN
# 3     ENSG00000105641   HEK293T            None
# 4     ENSG00000105641       NaN             NaN
# ...               ...       ...             ...
# 2584  ENSG00000181072      None  cardiovascular
# 2585  ENSG00000181072      None  nervous system
# 2585  ENSG00000181072      None     respiratory
# 2585  ENSG00000181072      None  cardiovascular
# 2586  ENSG00000185231     HepG2            None
#
#                                                 event           datasource
# 0                       Cognitive Function, Decreased             AOP-Wiki
# 1                    Altered, Amphibian metamorphosis             AOP-Wiki
# 2     Increase, Adenomas/carcinomas (follicular cell)             AOP-Wiki
# 3                  regulation of transporter activity              ToxCast
# 4                       Cognitive Function, Decreased             AOP-Wiki
# ...                                               ...                  ...
# 2584               increased/decreased blood pressure  Lynch et al. (2017)
# 2585                                     irritability  Lynch et al. (2017)
# 2585                                     irritability  Lynch et al. (2017)
# 2585                                     irritability  Lynch et al. (2017)
# 2586      regulation of transcription factor activity              ToxCast
#
# [5585 rows x 5 columns]

# %%
#genes with not empty safety events
safety_genes=df["gene_id"][df["safetyLiabilities"].notna()]

# %%
# Choose a gene that has multiple entries
gene = "ENSG00000105641"
safety_df[safety_df["gene_id"]==gene]
# Out:
#            gene_id cellLabel tissueLabel  \
# 0  ENSG00000105641       NaN         NaN
# 1  ENSG00000105641       NaN         NaN
# 2  ENSG00000105641       NaN         NaN
# 3  ENSG00000105641   HEK293T        None
# 4  ENSG00000105641       NaN         NaN
# 5  ENSG00000105641       NaN         NaN
#
#                                              event datasource
# 0                    Cognitive Function, Decreased   AOP-Wiki
# 1                 Altered, Amphibian metamorphosis   AOP-Wiki
# 2  Increase, Adenomas/carcinomas (follicular cell)   AOP-Wiki
# 3               regulation of transporter activity    ToxCast
# 4                    Cognitive Function, Decreased   AOP-Wiki
# 5                  Impairment, Learning and memory   AOP-Wiki

# %%
from pprint import pprint
from numpy import array

# %%
# Gene entry in input dataframe (merge of parquet files)
df["safetyLiabilities"][df["gene_id"]==gene]
# Out:
# 13    [{'event': 'Cognitive Function, Decreased', 'e...
# Name: safetyLiabilities, dtype: object

# %%
# Expanded information inside safetyLiabilities column
pprint(df["safetyLiabilities"][df["gene_id"]==gene].tolist())
# Out:
# [array([{'event': 'Cognitive Function, Decreased', 'eventId': 'HP_0100543', 'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object), 'biosamples': None, 'isHumanApplicable': None, 'datasource': 'AOP-Wiki', 'literature': None, 'url': 'https://aopwiki.org/aops/134', 'studies': None},
#        {'event': 'Altered, Amphibian metamorphosis', 'eventId': None, 'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object), 'biosamples': None, 'isHumanApplicable': False, 'datasource': 'AOP-Wiki', 'literature': None, 'url': 'https://aopwiki.org/aops/176', 'studies': None},
#        {'event': 'Increase, Adenomas/carcinomas (follicular cell)', 'eventId': 'EFO_0000616', 'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object), 'biosamples': None, 'isHumanApplicable': False, 'datasource': 'AOP-Wiki', 'literature': None, 'url': 'https://aopwiki.org/aops/110', 'studies': None},
#        {'event': 'regulation of transporter activity', 'eventId': None, 'effects': None, 'biosamples': array([{'cellFormat': 'cell line', 'cellLabel': 'HEK293T', 'tissueId': None, 'tissueLabel': None}],
#              dtype=object), 'isHumanApplicable': None, 'datasource': 'ToxCast', 'literature': None, 'url': 'https://www.epa.gov/chemical-research/exploring-toxcast-data-downloadable-data', 'studies': array([{'description': 'NIS_RAIU, is one of 2 assay component(s) measured or calculated from the NIS_Inhibition assay. It is designed to make measurements of enzyme activity, a form of enzyme reporter, as detected with 125-i signals by MicroBeta radioactivity plate reader technology.', 'name': 'NIS_RAIU_inhibition', 'type': None}],
#              dtype=object)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ,
#        {'event': 'Cognitive Function, Decreased', 'eventId': 'HP_0100543', 'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object), 'biosamples': None, 'isHumanApplicable': None, 'datasource': 'AOP-Wiki', 'literature': None, 'url': 'https://aopwiki.org/aops/65', 'studies': None},
#        {'event': 'Impairment, Learning and memory', 'eventId': 'EFO_0001072', 'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object), 'biosamples': None, 'isHumanApplicable': None, 'datasource': 'AOP-Wiki', 'literature': None, 'url': 'https://aopwiki.org/aops/54', 'studies': None}],
#       dtype=object)]

# %%
# Keep only two entries to build test dataframe
varList=df["safetyLiabilities"][df["gene_id"]==gene].tolist()[0].tolist()[2:4]
varList
# Out:
# [{'event': 'Increase, Adenomas/carcinomas (follicular cell)',
#   'eventId': 'EFO_0000616',
#   'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object),
#   'biosamples': None,
#   'isHumanApplicable': False,
#   'datasource': 'AOP-Wiki',
#   'literature': None,
#   'url': 'https://aopwiki.org/aops/110',
#   'studies': None},
#  {'event': 'regulation of transporter activity',
#   'eventId': None,
#   'effects': None,
#   'biosamples': array([{'cellFormat': 'cell line', 'cellLabel': 'HEK293T', 'tissueId': None, 'tissueLabel': None}],
#         dtype=object),
#   'isHumanApplicable': None,
#   'datasource': 'ToxCast',
#   'literature': None,
#   'url': 'https://www.epa.gov/chemical-research/exploring-toxcast-data-downloadable-data',
#   'studies': array([{'description': 'NIS_RAIU, is one of 2 assay component(s) measured or calculated from the NIS_Inhibition assay. It is designed to make measurements of enzyme activity, a form of enzyme reporter, as detected with 125-i signals by MicroBeta radioactivity plate reader technology.', 'name': 'NIS_RAIU_inhibition', 'type': None}],
#         dtype=object)}]

# %%
# Manual construction of varlist
varList= [{'event': 'Increase, Adenomas/carcinomas (follicular cell)',
  'eventId': 'EFO_0000616',
  'effects': array([{'direction': 'inhibition', 'dosing': None}], dtype=object),
  'biosamples': None,
  'isHumanApplicable': False,
  'datasource': 'AOP-Wiki',
  'literature': None,
  'url': 'https://aopwiki.org/aops/110',
  'studies': None},
 {'event': 'regulation of transporter activity',
  'eventId': None,
  'effects': None,
  'biosamples': array([{'cellFormat': 'cell line', 'cellLabel': 'HEK293T', 'tissueId': None, 'tissueLabel': None}],
        dtype=object),
  'isHumanApplicable': None,
  'datasource': 'ToxCast',
  'literature': None,
  'url': 'https://www.epa.gov/chemical-research/exploring-toxcast-data-downloadable-data',
  'studies': array([{'description': 'NIS_RAIU, is one of 2 assay component(s) measured or calculated from the NIS_Inhibition assay. It is designed to make measurements of enzyme activity, a form of enzyme reporter, as detected with 125-i signals by MicroBeta radioactivity plate reader technology.', 'name': 'NIS_RAIU_inhibition', 'type': None}],
        dtype=object)}]

# %%
test = pd.DataFrame({"gene_id": gene, "tractability": [None], 
"safetyLiabilities":[varList]})
test
# Out:
#            gene_id tractability  \
# 0  ENSG00000105641         None
#
#                                    safetyLiabilities
# 0  [{'event': 'Increase, Adenomas/carcinomas (fol...

# %%
# Original input dataframe
df[df.gene_id==gene]
# Out:
#             gene_id                                       tractability  \
# 13  ENSG00000105641  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
#
#                                     safetyLiabilities
# 13  [{'event': 'Cognitive Function, Decreased', 'e...

# %%
expected = pd.DataFrame({"gene_id": ["ENSG00000163586", "ENSG00000163586"], 
        "cellLabel": [np.nan, "HepaRG"],
        "tissueLabel": [np.nan, np.nan],
        "event": ["Increase, Adenomas/carcinomas (follicular cell)", "regulation of transcription factor activity"],
        "datasource": ["AOP-Wiki", "ToxCast"]})
expected
# Out:
#            gene_id cellLabel  tissueLabel  \
# 0  ENSG00000163586       NaN          NaN
# 1  ENSG00000163586    HepaRG          NaN
#
#                                              event datasource
# 0  Increase, Adenomas/carcinomas (follicular cell)   AOP-Wiki
# 1      regulation of transcription factor activity    ToxCast

# %%
df_temp1=test.explode("safetyLiabilities")
df_temp1.dropna(subset=[col_explode], inplace=True)
df_temp1.reset_index(inplace=True)
df_temp1.head()
# Out:
#    index          gene_id tractability  \
# 0      0  ENSG00000105641         None
# 1      0  ENSG00000105641         None
#
#                                    safetyLiabilities
# 0  {'event': 'Increase, Adenomas/carcinomas (foll...
# 1  {'event': 'regulation of transporter activity'...

# %%
test2=df[df["gene_id"]==gene]
test2.explode(col_explode)
test2.reset_index(inplace=True)
test2
# Out:
#    index          gene_id                                       tractability  \
# 0     13  ENSG00000105641  [{'modality': 'SM', 'id': 'Approved Drug', 'va...
#
#                                    safetyLiabilities
# 0  [{'event': 'Cognitive Function, Decreased', 'e...

# %%
test2[col_explode].apply(pd.Series, dtype="object")
# Out:
#                                                    0  \
# 0  {'event': 'Cognitive Function, Decreased', 'ev...
#
#                                                    1  \
# 0  {'event': 'Altered, Amphibian metamorphosis', ...
#
#                                                    2  \
# 0  {'event': 'Increase, Adenomas/carcinomas (foll...
#
#                                                    3  \
# 0  {'event': 'regulation of transporter activity'...
#
#                                                    4  \
# 0  {'event': 'Cognitive Function, Decreased', 'ev...
#
#                                                    5
# 0  {'event': 'Impairment, Learning and memory', '...

# %%
df_temp2 = df_temp1[col_explode].apply(pd.Series, dtype="object")
df_temp2.head()
# Out:
#                                              event      eventId  \
# 0  Increase, Adenomas/carcinomas (follicular cell)  EFO_0000616
# 1               regulation of transporter activity         None
#
#                                          effects  \
# 0  [{'direction': 'inhibition', 'dosing': None}]
# 1                                           None
#
#                                           biosamples isHumanApplicable  \
# 0                                               None             False
# 1  [{'cellFormat': 'cell line', 'cellLabel': 'HEK...              None
#
#   datasource literature                                                url  \
# 0   AOP-Wiki       None                       https://aopwiki.org/aops/110
# 1    ToxCast       None  https://www.epa.gov/chemical-research/explorin...
#
#                                              studies
# 0                                               None
# 1  [{'description': 'NIS_RAIU, is one of 2 assay ...

# %%
df_temp3 = df_temp2.explode("biosamples")
df_temp3
# Out:
#                                              event      eventId  \
# 0  Increase, Adenomas/carcinomas (follicular cell)  EFO_0000616
# 1               regulation of transporter activity         None
#
#                                          effects  \
# 0  [{'direction': 'inhibition', 'dosing': None}]
# 1                                           None
#
#                                           biosamples isHumanApplicable  \
# 0                                               None             False
# 1  {'cellFormat': 'cell line', 'cellLabel': 'HEK2...              None
#
#   datasource literature                                                url  \
# 0   AOP-Wiki       None                       https://aopwiki.org/aops/110
# 1    ToxCast       None  https://www.epa.gov/chemical-research/explorin...
#
#                                              studies
# 0                                               None
# 1  [{'description': 'NIS_RAIU, is one of 2 assay ...

# %%
df_temp3["biosamples"].apply(pd.Series, dtype="object")
# Out:
#   cellFormat cellLabel  tissueId  tissueLabel
# 0        NaN       NaN       NaN          NaN
# 1  cell line   HEK293T       NaN          NaN

# %%
# Drop rows with missing values in safetyLiabilities

df_temp2 = df_temp1[col_explode].apply(pd.Series, dtype="object")
df_temp3 = df_temp2.explode("biosamples")
df_temp4 = df_temp3["biosamples"].apply(pd.Series, dtype="object")[["cellLabel", "tissueLabel"]]


# Concatenate all temporary dataframes into one
df_concat = pd.concat([df_temp1, df_temp2, df_temp4], axis=1)

# Subset for columns of interest
df_subset = df_concat[cols_subset_ls]
df_subset
# Out:
#            gene_id cellLabel  tissueLabel  \
# 0  ENSG00000105641       NaN          NaN
# 1  ENSG00000105641   HEK293T          NaN
#
#                                              event datasource
# 0  Increase, Adenomas/carcinomas (follicular cell)   AOP-Wiki
# 1               regulation of transporter activity    ToxCast

# %%
# Compare to expected df
expected
# Out:
#            gene_id cellLabel  tissueLabel  \
# 0  ENSG00000163586       NaN          NaN
# 1  ENSG00000163586    HepaRG          NaN
#
#                                              event datasource
# 0  Increase, Adenomas/carcinomas (follicular cell)   AOP-Wiki
# 1      regulation of transcription factor activity    ToxCast
