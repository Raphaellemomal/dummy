# %% [markdown]
# # CollecTRI_01_resource_aggregation
# Test translated python code from original [CollecTRI_01_resource_aggregation.R](https://github.com/saezlab/CollecTRI/blob/main/scripts/CollecTRI/01_resource_aggregation.R) to retrieve:
# * Number of activating and repressing interactions per TF-target pair
# * TF class: Lambert, coTF etc

# %%
import os
import pandas as pd
import re

# %% [markdown]
# ## Load and prepare data

# %%
# Load and prepare data
collecTRI_raw = pd.read_csv("CollecTRI_source.tsv", sep="\t", dtype="str")

print(collecTRI_raw.shape)
collecTRI_raw.head()
# Out:
# (51850, 55)
#         TF:TG Transcription Factor (Associated Gene Name)  \
# 0    MYC:TERT                                         MYC
# 1     AP1:CAT                                         AP1
# 2  SPI1:BGLAP                                        SPI1
# 3   AP1:ADAM2                                         AP1
# 4     AP1:JUN                                         AP1
#
#   Target Gene (Associated Gene Name) [ExTRI] Confidence  \
# 0                               TERT               High
# 1                                CAT               High
# 2                              BGLAP                Low
# 3                              ADAM2               High
# 4                                JUN               High
#
#                                         [ExTRI] PMID [ExTRI] present  \
# 0  10022128;10022128;10022128;10491298;10491298;1...           ExTRI
# 1  10022519;10329043;12036993;12538496;17935786;7...           ExTRI
# 2                                           10022617           ExTRI
# 3  10022869;10644332;11741970;11741970;18045590;1...           ExTRI
# 4  10022869;10022869;10037172;10208431;10366004;1...           ExTRI
#
#   [HTRI] present                                   [HTRI] Technique  \
# 0           HTRI  Chromatin Immunoprecipitation|Chromatin Immuno...
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
#
#          [HTRI] PMID [HTRI] Confidence  ...  [DoRothEA_A] PMID  \
# 0  11274400|12695333         High|High  ...  11274400;12695333
# 1                NaN               NaN  ...                NaN
# 2                NaN               NaN  ...                NaN
# 3                NaN               NaN  ...                NaN
# 4                NaN               NaN  ...                NaN
#
#   [DoRothEA_A] Directed [DoRothEA_A] Effect  Lambert  Lovering  GO:0003700  \
# 0                  TRUE           Stimulate  Lambert  Lovering  GO:0003700
# 1                   NaN                 NaN  Lambert  Lovering  GO:0003700
# 2                   NaN                 NaN  Lambert  Lovering  GO:0003700
# 3                   NaN                 NaN  Lambert  Lovering  GO:0003700
# 4                   NaN                 NaN  Lambert  Lovering  GO:0003700
#
#   GO:0140223 GO:0003712  TFClass Auto-regulation
# 0        NaN        NaN  TFClass             NaN
# 1        NaN        NaN  TFClass             NaN
# 2        NaN        NaN  TFClass             NaN
# 3        NaN        NaN  TFClass             NaN
# 4        NaN        NaN  TFClass             NaN
#
# [5 rows x 55 columns]

# %%
# Checkout columns
collecTRI_raw.columns.tolist()
# Out:
# ['TF:TG',
#  'Transcription Factor (Associated Gene Name)',
#  'Target Gene (Associated Gene Name)',
#  '[ExTRI] Confidence',
#  '[ExTRI] PMID',
#  '[ExTRI] present',
#  '[HTRI] present',
#  '[HTRI] Technique',
#  '[HTRI] PMID',
#  '[HTRI] Confidence',
#  '[TRRUST] present',
#  '[TRRUST] Regulation',
#  '[TRRUST] PMID',
#  '[TFactS] present',
#  '[TFactS] Sign',
#  '[TFactS] Species',
#  '[TFactS] Source',
#  '[TFactS] PMID',
#  '[TFactS] Confidence',
#  '[GOA] present',
#  '[GOA] Sign',
#  '[GOA] PMID',
#  '[IntAct] present',
#  '[IntAct] PMID',
#  '[IntAct] Method ID',
#  '[SIGNOR] present',
#  '[SIGNOR] Effect',
#  '[SIGNOR] Sign',
#  '[SIGNOR] PMID',
#  '[CytReg] present',
#  '[CytReg] Assay type',
#  '[CytReg] species',
#  '[CytReg] Activation/Repression',
#  '[CytReg] PMID',
#  '[CytReg] Year of publication',
#  '[GEREDB] present',
#  '[GEREDB] Effect',
#  '[GEREDB] PMID',
#  '[NTNU Curated] present',
#  '[NTNU Curated] Sign',
#  '[NTNU Curated] PMID',
#  '[Pavlidis2021] present',
#  '[Pavlidis2021] PMID',
#  '[Pavlidis2021] Mode of action',
#  '[DoRothEA_A] present',
#  '[DoRothEA_A] PMID',
#  '[DoRothEA_A] Directed',
#  '[DoRothEA_A] Effect',
#  'Lambert',
#  'Lovering',
#  'GO:0003700',
#  'GO:0140223',
#  'GO:0003712',
#  'TFClass',
#  'Auto-regulation']

# %%
# Unify column names across resources
collecTRI_raw.columns = (
    collecTRI_raw.columns.str.replace(r" ", "_", regex=True)
    .str.replace(r"[", "", regex=True).str.replace(r"]", "", regex=True)
    .str.replace(r"(", "", regex=True).str.replace(r")", "", regex=True)
    .str.replace(r"SIGNOR_Effect", "SIGNOR_effectType")
    .str.replace(r"Effect", "Regulation")
    .str.replace(r"Sign", "Regulation")
    .str.replace(r"Activation/Repression", "Regulation", regex=True)
    .str.replace(r"Mode_of_action", "Regulation", regex=True)
    .str.replace(r":", "_")
)


collecTRI_raw.columns.tolist()
# Out:
# ['Transcription_Factor_Associated_Gene_Name',
#  'Target_Gene_Associated_Gene_Name',
#  'ExTRI_Confidence',
#  'ExTRI_PMID',
#  'ExTRI_present',
#  'HTRI_present',
#  'HTRI_Technique',
#  'HTRI_PMID',
#  'HTRI_Confidence',
#  'TRRUST_present',
#  'TRRUST_Regulation',
#  'TRRUST_PMID',
#  'TFactS_present',
#  'TFactS_Regulation',
#  'TFactS_Species',
#  'TFactS_Source',
#  'TFactS_PMID',
#  'TFactS_Confidence',
#  'GOA_present',
#  'GOA_Regulation',
#  'GOA_PMID',
#  'IntAct_present',
#  'IntAct_PMID',
#  'IntAct_Method_ID',
#  'SIGNOR_present',
#  'SIGNOR_effectType',
#  'SIGNOR_Regulation',
#  'SIGNOR_PMID',
#  'CytReg_present',
#  'CytReg_Assay_type',
#  'CytReg_species',
#  'CytReg_Regulation',
#  'CytReg_PMID',
#  'CytReg_Year_of_publication',
#  'GEREDB_present',
#  'GEREDB_Regulation',
#  'GEREDB_PMID',
#  'NTNU_Curated_present',
#  'NTNU_Curated_Regulation',
#  'NTNU_Curated_PMID',
#  'Pavlidis2021_present',
#  'Pavlidis2021_PMID',
#  'Pavlidis2021_Regulation',
#  'DoRothEA_A_present',
#  'DoRothEA_A_PMID',
#  'DoRothEA_A_Directed',
#  'DoRothEA_A_Regulation',
#  'Lambert',
#  'Lovering',
#  'GO_0003700',
#  'GO_0140223',
#  'GO_0003712',
#  'TFClass',
#  'Auto-regulation']

# %%
# Quick description of dataset: check missing values
collecTRI_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51850 entries, 0 to 51849
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   TF_TG                                      51850 non-null  object
#  1   Transcription_Factor_Associated_Gene_Name  51850 non-null  object
#  2   Target_Gene_Associated_Gene_Name           51850 non-null  object
#  3   ExTRI_Confidence                           33670 non-null  object
#  4   ExTRI_PMID                                 33670 non-null  object
#  5   ExTRI_present                              33670 non-null  object
#  6   HTRI_present                               2346 non-null   object
#  7   HTRI_Technique                             2346 non-null   object
#  8   HTRI_PMID                                  2346 non-null   object
#  9   HTRI_Confidence                            2346 non-null   object
#  10  TRRUST_present                             8767 non-null   object
#  11  TRRUST_Regulation                          8767 non-null   object
#  12  TRRUST_PMID                                8767 non-null   object
#  13  TFactS_present                             6890 non-null   object
#  14  TFactS_Regulation                          3341 non-null   object
#  15  TFactS_Species                             6888 non-null   object
#  16  TFactS_Source                              6888 non-null   object
#  17  TFactS_PMID                                3488 non-null   object
#  18  TFactS_Confidence                          6890 non-null   object
#  19  GOA_present                                2021 non-null   object
#  20  GOA_Regulation                             2021 non-null   object
#  21  GOA_PMID                                   1335 non-null   object
#  22  IntAct_present                             419 non-null    object
#  23  IntAct_PMID                                419 non-null    object
#  24  IntAct_Method_ID                           419 non-null    object
#  25  SIGNOR_present                             3047 non-null   object
#  26  SIGNOR_effectType                          3047 non-null   object
#  27  SIGNOR_Regulation                          3047 non-null   object
#  28  SIGNOR_PMID                                3047 non-null   object
#  29  CytReg_present                             1316 non-null   object
#  30  CytReg_Assay_type                          1316 non-null   object
#  31  CytReg_species                             1316 non-null   object
#  32  CytReg_Regulation                          1303 non-null   object
#  33  CytReg_PMID                                1316 non-null   object
#  34  CytReg_Year_of_publication                 1316 non-null   object
#  35  GEREDB_present                             7891 non-null   object
#  36  GEREDB_Regulation                          7891 non-null   object
#  37  GEREDB_PMID                                7891 non-null   object
#  38  NTNU_Curated_present                       9896 non-null   object
#  39  NTNU_Curated_Regulation                    7689 non-null   object
#  40  NTNU_Curated_PMID                          7689 non-null   object
#  41  Pavlidis2021_present                       1474 non-null   object
#  42  Pavlidis2021_PMID                          1474 non-null   object
#  43  Pavlidis2021_Regulation                    1474 non-null   object
#  44  DoRothEA_A_present                         6333 non-null   object
#  45  DoRothEA_A_PMID                            2328 non-null   object
#  46  DoRothEA_A_Directed                        6277 non-null   object
#  47  DoRothEA_A_Regulation                      6277 non-null   object
#  48  Lambert                                    45259 non-null  object
#  49  Lovering                                   43501 non-null  object
#  50  GO_0003700                                 43459 non-null  object
#  51  GO_0140223                                 351 non-null    object
#  52  GO_0003712                                 6765 non-null   object
#  53  TFClass                                    46322 non-null  object
#  54  Auto-regulation                            492 non-null    object
# dtypes: object(55)
# memory usage: 21.8+ MB

# %%
# Set 'TF_TG' as the index
collecTRI_raw.set_index("TF_TG", inplace=True)

# %%
# Check resources with PMID information
resources = [
    resource.replace("_PMID", "")
    for resource in collecTRI_raw.columns
    if re.search(r"PMID", resource)
]

print(len(resources))
resources
# Out:
# 12
# ['ExTRI',
#  'HTRI',
#  'TRRUST',
#  'TFactS',
#  'GOA',
#  'IntAct',
#  'SIGNOR',
#  'CytReg',
#  'GEREDB',
#  'NTNU_Curated',
#  'Pavlidis2021',
#  'DoRothEA_A']

# %%
# Check resources with Regulation information (Not all resources have regulation ifonfo)
resources_reg = [
    resource.replace("_Regulation", "")
    for resource in collecTRI_raw.columns
    if re.search(r"Regulation", resource)
]

print(len(resources_reg))
resources_reg
# Out:
# 9
# ['TRRUST',
#  'TFactS',
#  'GOA',
#  'SIGNOR',
#  'CytReg',
#  'GEREDB',
#  'NTNU_Curated',
#  'Pavlidis2021',
#  'DoRothEA_A']

# %%
# Filter for dataframe containing only PMIDs and associated modes of regulation
df_merge = pd.merge(collecTRI_raw.filter(regex="PMID"), collecTRI_raw.filter(regex="Regulation"), left_index=True, right_index=True)

df_merge.reset_index(inplace=True)
df_merge
# Out:
#              TF_TG                                         ExTRI_PMID  \
# 0         MYC:TERT  10022128;10022128;10022128;10491298;10491298;1...
# 1          AP1:CAT  10022519;10329043;12036993;12538496;17935786;7...
# 2       SPI1:BGLAP                                           10022617
# 3        AP1:ADAM2  10022869;10644332;11741970;11741970;18045590;1...
# 4          AP1:JUN  10022869;10022869;10037172;10208431;10366004;1...
# ...            ...                                                ...
# 51845  TWIST1:MDM2                                                NaN
# 51846  USF1:NUP188                                                NaN
# 51847      VDR:ELL                                                NaN
# 51848    VDR:PTK2B                                                NaN
# 51849  ZNF148:RNLS                                                NaN
#
#                HTRI_PMID                                        TRRUST_PMID  \
# 0      11274400|12695333  10022128;15595642;18226852;18754863;21132266;2...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                   9502786|19671687
# ...                  ...                                                ...
# 51845                NaN                                                NaN
# 51846                NaN                                                NaN
# 51847                NaN                                                NaN
# 51848                NaN                                                NaN
# 51849                NaN                                                NaN
#
#       TFactS_PMID GOA_PMID IntAct_PMID SIGNOR_PMID CytReg_PMID GEREDB_PMID  \
# 0        14519204      NaN         NaN         NaN         NaN         NaN
# 1             NaN      NaN         NaN         NaN         NaN         NaN
# 2             NaN      NaN         NaN         NaN         NaN         NaN
# 3             NaN      NaN         NaN         NaN         NaN         NaN
# 4             |||      NaN         NaN         NaN         NaN         NaN
# ...           ...      ...         ...         ...         ...         ...
# 51845         NaN      NaN         NaN         NaN         NaN         NaN
# 51846         NaN      NaN         NaN         NaN         NaN         NaN
# 51847         NaN      NaN         NaN         NaN         NaN         NaN
# 51848         NaN      NaN         NaN         NaN         NaN         NaN
# 51849         NaN      NaN         NaN         NaN         NaN         NaN
#
#        ...    DoRothEA_A_PMID   TRRUST_Regulation TFactS_Regulation  \
# 0      ...  11274400;12695333  Activation|Unknown                UP
# 1      ...                NaN                 NaN               NaN
# 2      ...                NaN                 NaN               NaN
# 3      ...                NaN                 NaN               NaN
# 4      ...                NaN  Activation|Unknown               |||
# ...    ...                ...                 ...               ...
# 51845  ...                NaN                 NaN               NaN
# 51846  ...           22951020                 NaN               NaN
# 51847  ...                NaN                 NaN               NaN
# 51848  ...                NaN                 NaN               NaN
# 51849  ...           25295465                 NaN               NaN
#
#       GOA_Regulation SIGNOR_Regulation CytReg_Regulation GEREDB_Regulation  \
# 0                 UP               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# ...              ...               ...               ...               ...
# 51845            NaN               NaN               NaN               NaN
# 51846            NaN               NaN               NaN               NaN
# 51847            NaN               NaN               NaN               NaN
# 51848            NaN               NaN               NaN               NaN
# 51849            NaN               NaN               NaN               NaN
#
#       NTNU_Curated_Regulation  \
# 0                      +|-|||
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                    -|+||||+
# ...                       ...
# 51845                     NaN
# 51846                     NaN
# 51847                     NaN
# 51848                     NaN
# 51849                     NaN
#
#                                Pavlidis2021_Regulation DoRothEA_A_Regulation
# 0      not_applicable|activation|activation|activation             Stimulate
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
# 3                                                  NaN                   NaN
# 4                                                  NaN                   NaN
# ...                                                ...                   ...
# 51845                                              NaN               Unknown
# 51846                                              NaN             Stimulate
# 51847                                              NaN               Unknown
# 51848                                              NaN               Unknown
# 51849                                              NaN             Stimulate
#
# [51850 rows x 22 columns]

# %%
# Homogenize regulation modes
# NOTE: This does not work everywhere so perhaps do it later
df_merge.replace(["+", "activation", "Activation", "positive", "Stimulate", "UP"], 'activation', inplace=True)
df_merge.replace(["-", "DOWN", "Inhibit", "negative","Repression"], "repression", inplace=True)
df_merge.replace(["", "?", "+_-", "not_applicable","Unknown"], "unknown", inplace=True)

df_merge
# Out:
#              TF_TG                                         ExTRI_PMID  \
# 0         MYC:TERT  10022128;10022128;10022128;10491298;10491298;1...
# 1          AP1:CAT  10022519;10329043;12036993;12538496;17935786;7...
# 2       SPI1:BGLAP                                           10022617
# 3        AP1:ADAM2  10022869;10644332;11741970;11741970;18045590;1...
# 4          AP1:JUN  10022869;10022869;10037172;10208431;10366004;1...
# ...            ...                                                ...
# 51845  TWIST1:MDM2                                                NaN
# 51846  USF1:NUP188                                                NaN
# 51847      VDR:ELL                                                NaN
# 51848    VDR:PTK2B                                                NaN
# 51849  ZNF148:RNLS                                                NaN
#
#                HTRI_PMID                                        TRRUST_PMID  \
# 0      11274400|12695333  10022128;15595642;18226852;18754863;21132266;2...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                   9502786|19671687
# ...                  ...                                                ...
# 51845                NaN                                                NaN
# 51846                NaN                                                NaN
# 51847                NaN                                                NaN
# 51848                NaN                                                NaN
# 51849                NaN                                                NaN
#
#       TFactS_PMID GOA_PMID IntAct_PMID SIGNOR_PMID CytReg_PMID GEREDB_PMID  \
# 0        14519204      NaN         NaN         NaN         NaN         NaN
# 1             NaN      NaN         NaN         NaN         NaN         NaN
# 2             NaN      NaN         NaN         NaN         NaN         NaN
# 3             NaN      NaN         NaN         NaN         NaN         NaN
# 4             |||      NaN         NaN         NaN         NaN         NaN
# ...           ...      ...         ...         ...         ...         ...
# 51845         NaN      NaN         NaN         NaN         NaN         NaN
# 51846         NaN      NaN         NaN         NaN         NaN         NaN
# 51847         NaN      NaN         NaN         NaN         NaN         NaN
# 51848         NaN      NaN         NaN         NaN         NaN         NaN
# 51849         NaN      NaN         NaN         NaN         NaN         NaN
#
#        ...    DoRothEA_A_PMID   TRRUST_Regulation TFactS_Regulation  \
# 0      ...  11274400;12695333  Activation|Unknown        activation
# 1      ...                NaN                 NaN               NaN
# 2      ...                NaN                 NaN               NaN
# 3      ...                NaN                 NaN               NaN
# 4      ...                NaN  Activation|Unknown               |||
# ...    ...                ...                 ...               ...
# 51845  ...                NaN                 NaN               NaN
# 51846  ...           22951020                 NaN               NaN
# 51847  ...                NaN                 NaN               NaN
# 51848  ...                NaN                 NaN               NaN
# 51849  ...           25295465                 NaN               NaN
#
#       GOA_Regulation SIGNOR_Regulation CytReg_Regulation GEREDB_Regulation  \
# 0         activation               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# ...              ...               ...               ...               ...
# 51845            NaN               NaN               NaN               NaN
# 51846            NaN               NaN               NaN               NaN
# 51847            NaN               NaN               NaN               NaN
# 51848            NaN               NaN               NaN               NaN
# 51849            NaN               NaN               NaN               NaN
#
#       NTNU_Curated_Regulation  \
# 0                      +|-|||
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                    -|+||||+
# ...                       ...
# 51845                     NaN
# 51846                     NaN
# 51847                     NaN
# 51848                     NaN
# 51849                     NaN
#
#                                Pavlidis2021_Regulation DoRothEA_A_Regulation
# 0      not_applicable|activation|activation|activation            activation
# 1                                                  NaN                   NaN
# 2                                                  NaN                   NaN
# 3                                                  NaN                   NaN
# 4                                                  NaN                   NaN
# ...                                                ...                   ...
# 51845                                              NaN               unknown
# 51846                                              NaN            activation
# 51847                                              NaN               unknown
# 51848                                              NaN               unknown
# 51849                                              NaN            activation
#
# [51850 rows x 22 columns]

# %%
# TEST MELTING OF DATAFRAME
# DO Subset of df_merge for test
df_merge = df_merge[:3]
display(df_merge)
# Out:
#         TF_TG                                         ExTRI_PMID  \
# 0    MYC:TERT  10022128;10022128;10022128;10491298;10491298;1...
# 1     AP1:CAT  10022519;10329043;12036993;12538496;17935786;7...
# 2  SPI1:BGLAP                                           10022617
#
#            HTRI_PMID                                        TRRUST_PMID  \
# 0  11274400|12695333  10022128;15595642;18226852;18754863;21132266;2...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
#
#   TFactS_PMID GOA_PMID IntAct_PMID SIGNOR_PMID CytReg_PMID GEREDB_PMID  ...  \
# 0    14519204      NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN      NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN      NaN         NaN         NaN         NaN         NaN  ...
#
#      DoRothEA_A_PMID   TRRUST_Regulation TFactS_Regulation GOA_Regulation  \
# 0  11274400;12695333  Activation|Unknown        activation     activation
# 1                NaN                 NaN               NaN            NaN
# 2                NaN                 NaN               NaN            NaN
#
#   SIGNOR_Regulation CytReg_Regulation GEREDB_Regulation  \
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
#
#   NTNU_Curated_Regulation                          Pavlidis2021_Regulation  \
# 0                  +|-|||  not_applicable|activation|activation|activation
# 1                     NaN                                              NaN
# 2                     NaN                                              NaN
#
#   DoRothEA_A_Regulation
# 0            activation
# 1                   NaN
# 2                   NaN
#
# [3 rows x 22 columns]

# %%
# Define columns containing PMID and columns containing Regulation
## NOTE: this code can be used already before when merging dataframes for PMID and for Regulation

pmid_cols_ls = df_merge.columns[df_merge.columns.str.contains("PMID")].tolist()
print(pmid_cols_ls)

reg_cols_ls = df_merge.columns[df_merge.columns.str.contains("Regulation")].tolist()
print(reg_cols_ls)
# Out:
# ['ExTRI_PMID', 'HTRI_PMID', 'TRRUST_PMID', 'TFactS_PMID', 'GOA_PMID', 'IntAct_PMID', 'SIGNOR_PMID', 'CytReg_PMID', 'GEREDB_PMID', 'NTNU_Curated_PMID', 'Pavlidis2021_PMID', 'DoRothEA_A_PMID']
# ['TRRUST_Regulation', 'TFactS_Regulation', 'GOA_Regulation', 'SIGNOR_Regulation', 'CytReg_Regulation', 'GEREDB_Regulation', 'NTNU_Curated_Regulation', 'Pavlidis2021_Regulation', 'DoRothEA_A_Regulation']

# %%
# Melt dataframes independently, and then merge them


# Melt pmid df
df_pmid = pd.melt(df_merge, id_vars= "TF_TG", value_vars= pmid_cols_ls, var_name="resource", value_name="PMID")
df_pmid["resource"] = [txt.replace("_PMID", "") for txt in df_pmid["resource"]]
df_pmid["PMID"] = [str(txt).replace(";", ",") for txt in df_pmid["PMID"]]
df_pmid[df_pmid.TF_TG=="MYC:TERT"].sort_values("resource")
# Out:
#        TF_TG      resource                                               PMID
# 21  MYC:TERT        CytReg                                                nan
# 33  MYC:TERT    DoRothEA_A                                  11274400,12695333
# 0   MYC:TERT         ExTRI  10022128,10022128,10022128,10491298,10491298,1...
# 24  MYC:TERT        GEREDB                                                nan
# 12  MYC:TERT           GOA                                                nan
# 3   MYC:TERT          HTRI                                  11274400|12695333
# 15  MYC:TERT        IntAct                                                nan
# 27  MYC:TERT  NTNU_Curated                               11606399|11916966|||
# 30  MYC:TERT  Pavlidis2021                21627565|10022128|16880523|10022128
# 18  MYC:TERT        SIGNOR                                                nan
# 9   MYC:TERT        TFactS                                           14519204
# 6   MYC:TERT        TRRUST  10022128,15595642,18226852,18754863,21132266,2...

# %%
# Melt regulation df
df_reg = pd.melt(df_merge, id_vars=['TF_TG'], value_vars= reg_cols_ls, var_name="resource", value_name="regulation")
df_reg["resource"] = [txt.replace("_Regulation", "") for txt in df_reg["resource"]]
#df_reg.head(30)
df_reg[df_reg.TF_TG=="MYC:TERT"].sort_values("resource")
# Out:
#        TF_TG      resource                                       regulation
# 12  MYC:TERT        CytReg                                              NaN
# 24  MYC:TERT    DoRothEA_A                                       activation
# 15  MYC:TERT        GEREDB                                              NaN
# 6   MYC:TERT           GOA                                       activation
# 18  MYC:TERT  NTNU_Curated                                           +|-|||
# 21  MYC:TERT  Pavlidis2021  not_applicable|activation|activation|activation
# 9   MYC:TERT        SIGNOR                                              NaN
# 3   MYC:TERT        TFactS                                       activation
# 0   MYC:TERT        TRRUST                               Activation|Unknown

# %%
# Merge into final dataframe
TF_TG_df = pd.merge(df_pmid, df_reg, how="left", on=["TF_TG", "resource"])
TF_TG_df[TF_TG_df.TF_TG=="MYC:TERT"]
# Out:
#        TF_TG      resource                                               PMID  \
# 0   MYC:TERT         ExTRI  10022128,10022128,10022128,10491298,10491298,1...
# 3   MYC:TERT          HTRI                                  11274400|12695333
# 6   MYC:TERT        TRRUST  10022128,15595642,18226852,18754863,21132266,2...
# 9   MYC:TERT        TFactS                                           14519204
# 12  MYC:TERT           GOA                                                nan
# 15  MYC:TERT        IntAct                                                nan
# 18  MYC:TERT        SIGNOR                                                nan
# 21  MYC:TERT        CytReg                                                nan
# 24  MYC:TERT        GEREDB                                                nan
# 27  MYC:TERT  NTNU_Curated                               11606399|11916966|||
# 30  MYC:TERT  Pavlidis2021                21627565|10022128|16880523|10022128
# 33  MYC:TERT    DoRothEA_A                                  11274400,12695333
#
#                                          regulation
# 0                                               NaN
# 3                                               NaN
# 6                                Activation|Unknown
# 9                                        activation
# 12                                       activation
# 15                                              NaN
# 18                                              NaN
# 21                                              NaN
# 24                                              NaN
# 27                                           +|-|||
# 30  not_applicable|activation|activation|activation
# 33                                       activation

# %%
# Check what is inside rows to see format: Normally PMIDs are separated by "|" to differentiate IDs associated to the different regulation modes

# %%
TF_TG_df["regulation"][27]
# Out:
# '+|-|||'

# %%
TF_TG_df["PMID"][27]
# Out:
# '11606399|11916966|||'

# %%
TF_TG_df["regulation"][6]
# Out:
# 'Activation|Unknown'

# %%
TF_TG_df["PMID"][6]
# Out:
# '10022128,15595642,18226852,18754863,21132266,22207128|10637317,12941894,14611815,15958520,17706770,18093727,19912441,21553143,24705139'

# %%
# Can do a split of IDs and regulations modes into lists to then explode columns

# %%
str(TF_TG_df["PMID"][27]).split('|')
# Out:
# ['11606399', '11916966', '', '', '']

# %%
str(TF_TG_df["regulation"][27]).split('|')
# Out:
# ['+', '-', '', '', '']

# %%
str(TF_TG_df["PMID"][6]).split('|')
# Out:
# ['10022128,15595642,18226852,18754863,21132266,22207128',
#  '10637317,12941894,14611815,15958520,17706770,18093727,19912441,21553143,24705139']

# %%
# Check length after split
len(str(TF_TG_df["PMID"][6]).split('|'))
# Out:
# 2

# %%
# Using specific indices could access to the number of PMIDs related to a given regulation mode
str(TF_TG_df["PMID"][6]).split('|')[0]
# Out:
# '10022128,15595642,18226852,18754863,21132266,22207128'

# %%
# IMPORTANT TO CORRECT: Here lenght is 53 as it is taking everything as string: need to convert to list
len(str(TF_TG_df["PMID"][6]).split('|')[0])
# Out:
# 53

# %%
# Split IDs and regulation by "|"
TF_TG_df['PMID']= [str(txt).split('|') for txt in TF_TG_df['PMID']]
TF_TG_df['regulation']= [str(txt).split('|') for txt in TF_TG_df['regulation']]
TF_TG_df
# Out:
#          TF_TG      resource  \
# 0     MYC:TERT         ExTRI
# 1      AP1:CAT         ExTRI
# 2   SPI1:BGLAP         ExTRI
# 3     MYC:TERT          HTRI
# 4      AP1:CAT          HTRI
# 5   SPI1:BGLAP          HTRI
# 6     MYC:TERT        TRRUST
# 7      AP1:CAT        TRRUST
# 8   SPI1:BGLAP        TRRUST
# 9     MYC:TERT        TFactS
# 10     AP1:CAT        TFactS
# 11  SPI1:BGLAP        TFactS
# 12    MYC:TERT           GOA
# 13     AP1:CAT           GOA
# 14  SPI1:BGLAP           GOA
# 15    MYC:TERT        IntAct
# 16     AP1:CAT        IntAct
# 17  SPI1:BGLAP        IntAct
# 18    MYC:TERT        SIGNOR
# 19     AP1:CAT        SIGNOR
# 20  SPI1:BGLAP        SIGNOR
# 21    MYC:TERT        CytReg
# 22     AP1:CAT        CytReg
# 23  SPI1:BGLAP        CytReg
# 24    MYC:TERT        GEREDB
# 25     AP1:CAT        GEREDB
# 26  SPI1:BGLAP        GEREDB
# 27    MYC:TERT  NTNU_Curated
# 28     AP1:CAT  NTNU_Curated
# 29  SPI1:BGLAP  NTNU_Curated
# 30    MYC:TERT  Pavlidis2021
# 31     AP1:CAT  Pavlidis2021
# 32  SPI1:BGLAP  Pavlidis2021
# 33    MYC:TERT    DoRothEA_A
# 34     AP1:CAT    DoRothEA_A
# 35  SPI1:BGLAP    DoRothEA_A
#
#                                                  PMID  \
# 0   [10022128,10022128,10022128,10491298,10491298,...
# 1   [10022519,10329043,12036993,12538496,17935786,...
# 2                                          [10022617]
# 3                                [11274400, 12695333]
# 4                                               [nan]
# 5                                               [nan]
# 6   [10022128,15595642,18226852,18754863,21132266,...
# 7                                               [nan]
# 8                                               [nan]
# 9                                          [14519204]
# 10                                              [nan]
# 11                                              [nan]
# 12                                              [nan]
# 13                                              [nan]
# 14                                              [nan]
# 15                                              [nan]
# 16                                              [nan]
# 17                                              [nan]
# 18                                              [nan]
# 19                                              [nan]
# 20                                              [nan]
# 21                                              [nan]
# 22                                              [nan]
# 23                                              [nan]
# 24                                              [nan]
# 25                                              [nan]
# 26                                              [nan]
# 27                         [11606399, 11916966, , , ]
# 28                                              [nan]
# 29                                              [nan]
# 30           [21627565, 10022128, 16880523, 10022128]
# 31                                              [nan]
# 32                                              [nan]
# 33                                [11274400,12695333]
# 34                                              [nan]
# 35                                              [nan]
#
#                                            regulation
# 0                                               [nan]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5                                               [nan]
# 6                               [Activation, Unknown]
# 7                                               [nan]
# 8                                               [nan]
# 9                                        [activation]
# 10                                              [nan]
# 11                                              [nan]
# 12                                       [activation]
# 13                                              [nan]
# 14                                              [nan]
# 15                                              [nan]
# 16                                              [nan]
# 17                                              [nan]
# 18                                              [nan]
# 19                                              [nan]
# 20                                              [nan]
# 21                                              [nan]
# 22                                              [nan]
# 23                                              [nan]
# 24                                              [nan]
# 25                                              [nan]
# 26                                              [nan]
# 27                                       [+, -, , , ]
# 28                                              [nan]
# 29                                              [nan]
# 30  [not_applicable, activation, activation, activ...
# 31                                              [nan]
# 32                                              [nan]
# 33                                       [activation]
# 34                                              [nan]
# 35                                              [nan]

# %%
len(TF_TG_df["PMID"][6])
# Out:
# 2

# %%
len(TF_TG_df["regulation"][6])
# Out:
# 2

# %%
# If further splitting by comma, can calculate lenght of PMIDs per mode of regulation
len((TF_TG_df["PMID"][6][0].split(",")))
# Out:
# 6

# %%
TF_TG_df["regulation"][6][0].split(",")
# Out:
# ['Activation']

# %%
len(TF_TG_df["regulation"][6][1])
# Out:
# 7

# %%
pd.wide_to_long(TF_TG_df,['sur'],['TF_TG','resource'],'lol')
# Out:
# Empty DataFrame
# Columns: [regulation, PMID, sur]
# Index: []

# %%
TF_TG_df.head()
# Out:
#         TF_TG resource                                               PMID  \
# 0    MYC:TERT    ExTRI  [10022128,10022128,10022128,10491298,10491298,...
# 1     AP1:CAT    ExTRI  [10022519,10329043,12036993,12538496,17935786,...
# 2  SPI1:BGLAP    ExTRI                                         [10022617]
# 3    MYC:TERT     HTRI                               [11274400, 12695333]
# 4     AP1:CAT     HTRI                                              [nan]
#
#   regulation
# 0      [nan]
# 1      [nan]
# 2      [nan]
# 3      [nan]
# 4      [nan]

# %%
test=TF_TG_df.set_index(['TF_TG','resource']).apply(pd.Series).stack().reset_index()#.drop('level_3‌​',1)
val=test[0].apply(lambda x: x.count('|'))
test[test.TF_TG=="MYC:TERT"]
# Out:
#        TF_TG      resource     level_2  \
# 0   MYC:TERT         ExTRI        PMID
# 3   MYC:TERT          HTRI        PMID
# 6   MYC:TERT        TRRUST        PMID
# 7   MYC:TERT        TRRUST  regulation
# 10  MYC:TERT        TFactS        PMID
# 11  MYC:TERT        TFactS  regulation
# 14  MYC:TERT           GOA        PMID
# 15  MYC:TERT           GOA  regulation
# 18  MYC:TERT        IntAct        PMID
# 21  MYC:TERT        SIGNOR        PMID
# 24  MYC:TERT        CytReg        PMID
# 27  MYC:TERT        GEREDB        PMID
# 30  MYC:TERT  NTNU_Curated        PMID
# 31  MYC:TERT  NTNU_Curated  regulation
# 34  MYC:TERT  Pavlidis2021        PMID
# 35  MYC:TERT  Pavlidis2021  regulation
# 38  MYC:TERT    DoRothEA_A        PMID
# 39  MYC:TERT    DoRothEA_A  regulation
#
#                                                     0
# 0   10022128,10022128,10022128,10491298,10491298,1...
# 3                                   11274400|12695333
# 6   10022128,15595642,18226852,18754863,21132266,2...
# 7                                  Activation|Unknown
# 10                                           14519204
# 11                                         activation
# 14                                                nan
# 15                                         activation
# 18                                                nan
# 21                                                nan
# 24                                                nan
# 27                                                nan
# 30                               11606399|11916966|||
# 31                                             +|-|||
# 34                21627565|10022128|16880523|10022128
# 35    not_applicable|activation|activation|activation
# 38                                  11274400,12695333
# 39                                         activation

# %%
# Exploding not working as it is saying elements are not of same length, which is weird
test_explode =TF_TG_df.explode(['PMID','regulation'], ignore_index=True))
test_explode
# Out:
#   Cell In[87], line 2
#     test_explode =TF_TG_df.explode(['PMID','regulation'], ignore_index=True))
#                                                                             ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import numpy as np
technologies = ({'A': [["Spark","PySpark","Python"], 'Course', [], ["Java","pandas"]],
                   'B': 25000,
                   'C': [['30days','40days','35days'], np.nan, [], ['40days','55days']]})
df = pd.DataFrame(technologies)
print(df)

# Use DataFrame.explode() function
df2 = df.explode('A')
print(df2)

# Explode single column 
# Using DataFrame.explode()function
df2 = df.explode(list('A'))
print(df2)

# Explode single column & ignore_index
df2 = df.explode('A',ignore_index=True)
print(df2)

# Explode multiple columns 
# Using DataFrame.explode() function
df2 = df.explode(list('AC'))
print(df2)

# Use DataFrame.explode() Function & ignore_index
df2 = df.explode(list('A','C'), ignore_index=True)
print(df2)
# Out:
#                           A      B                         C
# 0  [Spark, PySpark, Python]  25000  [30days, 40days, 35days]
# 1                    Course  25000                       NaN
# 2                        []  25000                        []
# 3            [Java, pandas]  25000          [40days, 55days]
#          A      B                         C
# 0    Spark  25000  [30days, 40days, 35days]
# 0  PySpark  25000  [30days, 40days, 35days]
# 0   Python  25000  [30days, 40days, 35days]
# 1   Course  25000                       NaN
# 2      NaN  25000                        []
# 3     Java  25000          [40days, 55days]
# 3   pandas  25000          [40days, 55days]
#          A      B                         C
# 0    Spark  25000  [30days, 40days, 35days]
# 0  PySpark  25000  [30days, 40days, 35days]
# 0   Python  25000  [30days, 40days, 35days]
# 1   Course  25000                       NaN
# 2      NaN  25000                        []
# 3     Java  25000          [40days, 55days]
# 3   pandas  25000          [40days, 55days]
#          A      B                         C
# 0    Spark  25000  [30days, 40days, 35days]
# 1  PySpark  25000  [30days, 40days, 35days]
# 2   Python  25000  [30days, 40days, 35days]
# 3   Course  25000                       NaN
# 4      NaN  25000                        []
# 5     Java  25000          [40days, 55days]
# 6   pandas  25000          [40days, 55days]
#          A      B       C
# 0    Spark  25000  30days
# 0  PySpark  25000  40days
# 0   Python  25000  35days
# 1   Course  25000     NaN
# 2      NaN  25000     NaN
# 3     Java  25000  40days
# 3   pandas  25000  55days
#          A      B       C
# 0    Spark  25000  30days
# 1  PySpark  25000  40days
# 2   Python  25000  35days
# 3   Course  25000     NaN
# 4      NaN  25000     NaN
# 5     Java  25000  40days
# 6   pandas  25000  55days

# %%
list('AC')
# Out:
# ['A', 'C']
